# %%
#!/usr/bin/env python
# coding: utf-8
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(color_codes=True)

# %%
# Load data from path
TimeConstraint = pd.read_csv("data/GeneratedData.csv")

# %%
def main():
    print("NFV Data Visualization")
    print(TimeConstraint.head())
    print("Info")
    print(TimeConstraint.info())
    print("Describe")
    print(TimeConstraint.describe())
    f, ax = plt.subplots(1, figsize=(20,10))
    sns.regplot(x=TimeConstraint.CPU, y=TimeConstraint.throughput, data=TimeConstraint)
    plt.show()
    TimeConstraint.info()

# %%
main()
# Out:
# NFV Data Visualization
#    Unnamed: 0       CPU     throughput
# 0           0  0.070651   44373.474780
# 1           1  0.976907  442996.757953
# 2           2  0.952362  434875.867578
# 3           3  0.522444  273205.892370
# 4           4  0.507021  266587.599064
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
# Unnamed: 0    100 non-null int64
# CPU           100 non-null float64
# throughput    100 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 2.4 KB
# None
# Describe
#        Unnamed: 0         CPU     throughput
# count  100.000000  100.000000     100.000000
# mean    49.500000    0.503208  252689.739047
# std     29.011492    0.288193  128155.971076
# min      0.000000    0.001924    1249.384931
# 25%     24.750000    0.276605  158732.677129
# 50%     49.500000    0.497214  262343.870738
# 75%     74.250000    0.724415  354147.576609
# max     99.000000    0.999210  450288.917049
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
# Unnamed: 0    100 non-null int64
# CPU           100 non-null float64
# throughput    100 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 2.4 KB
