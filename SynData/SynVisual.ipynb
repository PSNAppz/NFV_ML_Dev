# %%
#!/usr/bin/env python
# coding: utf-8
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(color_codes=True)

# %%
# Load data from path
TimeConstraint = pd.read_csv("data/GeneratedData.csv")

# %%
def main():
    print("NFV Data Visualization")
    print(TimeConstraint.head())
    print("Info")
    print(TimeConstraint.info())
    print("Describe")
    print(TimeConstraint.describe())
    f, ax = plt.subplots(1, figsize=(20,10))
    sns.regplot(x=TimeConstraint.CPU, y=TimeConstraint.throughput, data=TimeConstraint)
    plt.show()
    TimeConstraint.info()

# %%
main()
# Out:
# NFV Data Visualization
#    Unnamed: 0       CPU    throughput
# 0           0  0.696526  34363.118465
# 1           1  0.941964  43149.733904
# 2           2  0.346472  19343.189040
# 3           3  0.430841  23292.332327
# 4           4  0.447844  24061.304102
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 3 columns):
# Unnamed: 0    3000 non-null int64
# CPU           3000 non-null float64
# throughput    3000 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 70.4 KB
# None
# Describe
#         Unnamed: 0          CPU    throughput
# count  3000.000000  3000.000000   3000.000000
# mean   1499.500000     0.493738  24828.910090
# std     866.169729     0.289316  12935.844699
# min       0.000000     0.000926     65.491559
# 25%     749.750000     0.238360  13903.014821
# 50%    1499.500000     0.493751  26089.888002
# 75%    2249.250000     0.739529  35992.883698
# max    2999.000000     0.999707  45053.216844
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 3 columns):
# Unnamed: 0    3000 non-null int64
# CPU           3000 non-null float64
# throughput    3000 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 70.4 KB
