# %%
#!/usr/bin/env python
# coding: utf-8
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(color_codes=True)

# %%
# Load data from path
TimeConstraint = pd.read_csv("data/GeneratedData.csv")

# %%
def main():
    print("NFV Data Visualization")
    print(TimeConstraint.head())
    print("Info")
    print(TimeConstraint.info())
    print("Describe")
    print(TimeConstraint.describe())
    f, ax = plt.subplots(1, figsize=(20,10))
    sns.regplot(x=TimeConstraint.CPU, y=TimeConstraint.throughput, data=TimeConstraint)
    plt.show()
    TimeConstraint.info()

# %%
main()
# Out:
# NFV Data Visualization
#    Unnamed: 0       CPU     throughput
# 0           0  0.563604  290545.802356
# 1           1  0.633196  318850.425693
# 2           2  0.689129  340738.288507
# 3           3  0.418945  227443.853120
# 4           4  0.777341  373826.920428
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
# Unnamed: 0    30 non-null int64
# CPU           30 non-null float64
# throughput    30 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 800.0 bytes
# None
# Describe
#        Unnamed: 0        CPU     throughput
# count   30.000000  30.000000      30.000000
# mean    14.500000   0.522868  264491.411347
# std      8.803408   0.255238  109731.530908
# min      0.000000   0.085521   53339.239605
# 25%      7.250000   0.327064  183913.565970
# 50%     14.500000   0.522418  273193.269189
# 75%     21.750000   0.685533  339348.568633
# max     29.000000   0.997311  449671.026306
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
# Unnamed: 0    30 non-null int64
# CPU           30 non-null float64
# throughput    30 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 800.0 bytes
