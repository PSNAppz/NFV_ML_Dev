# %%
#!/usr/bin/env python
# coding: utf-8
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(color_codes=True)

# %%
# Load data from path
TimeConstraint = pd.read_csv("data/GeneratedData.csv")

# %%
def main():
    print("NFV Data Visualization")
    print(TimeConstraint.head())
    print("Info")
    print(TimeConstraint.info())
    print("Describe")
    print(TimeConstraint.describe())
    f, ax = plt.subplots(1, figsize=(20,10))
    sns.regplot(x=TimeConstraint.CPU, y=TimeConstraint.throughput, data=TimeConstraint)
    plt.show()
    TimeConstraint.info()

# %%
main()
# Out:
# NFV Data Visualization
#    Unnamed: 0       CPU     throughput
# 0           0  0.842893  397368.775071
# 1           1  0.669229  333035.090849
# 2           2  0.241706  140716.093307
# 3           3  0.385587  211980.634371
# 4           4  0.076755   48068.596261
# Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 3 columns):
# Unnamed: 0    3000 non-null int64
# CPU           3000 non-null float64
# throughput    3000 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 70.4 KB
# None
# Describe
#         Unnamed: 0          CPU     throughput
# count  3000.000000  3000.000000    3000.000000
# mean   1499.500000     0.504492  252707.379896
# std     866.169729     0.292979  130297.938172
# min       0.000000     0.000062      40.249553
# 25%     749.750000     0.247911  143955.930747
# 50%    1499.500000     0.510654  268152.671476
# 75%    2249.250000     0.765320  369415.881288
# max    2999.000000     0.999946  450528.195015
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 3 columns):
# Unnamed: 0    3000 non-null int64
# CPU           3000 non-null float64
# throughput    3000 non-null float64
# dtypes: float64(2), int64(1)
# memory usage: 70.4 KB
